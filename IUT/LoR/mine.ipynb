# %%
import requests
import re
import json

 # customize the header dictionary for your need

headers = {
        'authority': 'www.daraz.com.bd',
        'pragma': 'no-cache',
        'cache-control': 'no-cache',
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'none',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-dest': 'document',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

# change the item_id, page_no and page_size as per the product
# this example will parse reviews of this product https://www.daraz.com.bd/products/t-i141964811-s1103036896.html
# https://www.daraz.com.bd/products/black-yellow-green-and-white-color-slides-slipper-sunztonz-light-weight-casual-style-sandal-for-men-i313736437-s1407292837.html?&search=pdp_v2v?spm=a2a0e.pdp.recommendation_1.2.408c7f36zZFBlV&mp=1&scm=1007.38553.252219.0&clickTrackInfo=da6f9bbc-b991-4b78-8e4f-02120dd0bbf5__313736437__9669__ext_i2i__330312__0.6__0.6__0.0__0.0__0.0__0.00188275__1__null__null__null__null__null__null____750.0__0.544__3.75__16__342.0__251350,277828,289196,310561,320949__null__null__null__3650.16544_955.3632_4559.21183__null__28556__null__0.0__0.0________null__null
#                                                                                                                  item id (above line) i313736437
item_id = '313736437'
page_no = 1
page_size = 5

review_url = f'https://my.daraz.com.bd/pdp/review/getReviewList?itemId={item_id}&pageSize={page_size}&filter=0&sort=0&pageNo={page_no}'
review_request = requests.get(review_url, headers=headers)
review_request
# Out:
# <Response [200]>

# %%
review_request.text
# Out:
# '<ReviewResultDTO><success>true</success><model><items><items><reviewRateId>40098796536437</reviewRateId><reviewType>PRODUCT_REVIEW</reviewType><buyerId>700050546509</buyerId><buyerName>B B.</buyerName><buyerEmail/><realBuyerName/><isAnonymous>false</isAnonymous><tradeOrderId/><source/><clientType>androidApp</clientType><rating>5</rating><originalRating/><reviewTitle/><reviewContent>সবকিছু ঠিক আছে ডেলিভারি দ্রুত ছিল/ গ্লু কোয়ালিটি নিয়ে সন্দেহ আছে/ কিন্তু overall দাম অনুযায়ী পারফেক্ট / চাইলে নিতে পারেন</reviewContent><reviewTime>1  week ago</reviewTime><zonedReviewTime/><likeCount>0</likeCount><likeText/><isMeLike/><helpful>true</helpful><rejected>false</rejected><rejectionReason/><resubmissionTooltip/><resubmissionMessage/><qcReasonId/><qcDate/><isPurchased>true</isPurchased><isGuest>false</isGuest><sellerId>700523190876</sellerId><sellerName/><boughtDate>22 Jul 2023</boughtDate><isBuyerShowEnabled>false</isBuyerShowEnabled><zonedBoughtDate/><reviewStatus>approved</reviewStatus><q
# ...

# %%
pip install xmltodict

# %%
import xmltodict, json

review_dict_list = xmltodict.parse(review_request.text)
review_dict_list
# Out:
# {'ReviewResultDTO': {'success': 'true',
#   'model': {'items': {'items': [{'reviewRateId': '40098796536437',
#       'reviewType': 'PRODUCT_REVIEW',
#       'buyerId': '700050546509',
#       'buyerName': 'B B.',
#       'buyerEmail': None,
#       'realBuyerName': None,
#       'isAnonymous': 'false',
#       'tradeOrderId': None,
#       'source': None,
#       'clientType': 'androidApp',
#       'rating': '5',
#       'originalRating': None,
#       'reviewTitle': None,
#       'reviewContent': 'সবকিছু ঠিক আছে ডেলিভারি দ্রুত ছিল/ গ্লু কোয়ালিটি নিয়ে সন্দেহ আছে/ কিন্তু overall দাম অনুযায়ী পারফেক্ট / চাইলে নিতে পারেন',
#       'reviewTime': '1  week ago',
#       'zonedReviewTime': None,
#       'likeCount': '0',
#       'likeText': None,
#       'isMeLike': None,
#       'helpful': 'true',
#       'rejected': 'false',
#       'rejectionReason': None,
#       'resubmissionTooltip': None,
#       'resubmissionMessage': None,
#       'qcReasonId': None,
#       'qcDate': None,
# ...

# %%
print(type(review_dict_list))
review_dict_list["ReviewResultDTO"]['model']['items']
# Out:
# <class 'dict'>
# {'items': [{'reviewRateId': '40098796536437',
#    'reviewType': 'PRODUCT_REVIEW',
#    'buyerId': '700050546509',
#    'buyerName': 'B B.',
#    'buyerEmail': None,
#    'realBuyerName': None,
#    'isAnonymous': 'false',
#    'tradeOrderId': None,
#    'source': None,
#    'clientType': 'androidApp',
#    'rating': '5',
#    'originalRating': None,
#    'reviewTitle': None,
#    'reviewContent': 'সবকিছু ঠিক আছে ডেলিভারি দ্রুত ছিল/ গ্লু কোয়ালিটি নিয়ে সন্দেহ আছে/ কিন্তু overall দাম অনুযায়ী পারফেক্ট / চাইলে নিতে পারেন',
#    'reviewTime': '1  week ago',
#    'zonedReviewTime': None,
#    'likeCount': '0',
#    'likeText': None,
#    'isMeLike': None,
#    'helpful': 'true',
#    'rejected': 'false',
#    'rejectionReason': None,
#    'resubmissionTooltip': None,
#    'resubmissionMessage': None,
#    'qcReasonId': None,
#    'qcDate': None,
#    'isPurchased': 'true',
#    'isGuest': 'false',
#    'sellerId': '700523190876',
#    'sellerName': None,
# ...
